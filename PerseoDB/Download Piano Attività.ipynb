# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import urllib
import pyodbc
import os

def connect_perseo_db():
    server = os.environ['PERSEO_IP']
    database = os.environ['PERSEO_DB']
    username = os.environ['PERSEO_USR']
    password = os.environ['PERSEO_PWD']
    
    params = urllib.parse.quote_plus("DRIVER={FreeTDS};"
                                     "SERVER="+server+";"
                                     "PORT=1433;"
                                     "DATABASE="+database+";"
                                     "UID="+username+";"
                                     "PWD="+password+";"
                                     "Trusted_Connection=no")
    
    conn = create_engine("mssql+pyodbc:///?odbc_connect={}".format(params))
    return conn

def readSqlData(file_name):
    file = open(file_name, mode='r')
    query = file.read()
    file.close()

    engine = connect_perseo_db()
    return pd.read_sql(query, engine)

# %%
# Leggi l'elenco attività
dati = readSqlData('Attività/Elenco Servizi.sql')

dati[['OreAula', 'OreStage']] = dati[['OreAula', 'OreStage']].fillna(0)
dati = dati.set_index('IDedizione')

# %%
# Aggiungi i dati sulle doti (numero e importo)
doti = readSqlData('Ricavi/Doti.sql')

doti = doti.set_index('IDedizione')

dati = dati.join(doti[['NumeroDoti', 'ImportoDoti']])
dati[['NumeroDoti', 'ImportoDoti']] = dati[['NumeroDoti', 'ImportoDoti']].fillna(0)

# %%
# Aggiungi i dati sulle fatture collaboratori
fatture = readSqlData('Costi/Fatture collaboratori.sql')

fatture['Attivita'] = fatture['TipoAttivita'].map({
    'DOCENZA': 'Docenza',
    'ELABORAZIONE MATERIALE DIDATTICO': 'Docenza',
    'FORMAZIONE IN ASSETTO LAVORATIVO EXTRA MONTE ORE': 'Docenza',
    'TUTOR': 'Tutoraggio',
    'CODOCENZA': 'Docenza',
    'SOSTEGNO': 'Tutoraggio',
    'ATTIVITÀ PREVISTA DAL PROGETTO': 'Amministrazione e segreteria',
    'SERVIZI PERSONALIZZATI': 'Tutoraggio',
    'TUTOR D\'AULA': 'Tutoraggio',
    'SOSTEGNO FUORI AULA': 'Tutoraggio',
    'ORIENTAMENTO': 'Orientamento',
    'COORDINAMENTO': 'Progettazione e coordinamento',
    'ESAME': 'Esami',
    'SOSTEGNO FINANZIATO': 'Tutoraggio',
    'PROMOZIONE INTERVENTO': 'Promozione',
    'SOSTEGNO FINANZIATO FUORI AULA': 'Tutoraggio',
    'PROGETTAZIONE E PROGRAMMAZIONE DIDATTICA': 'Progettazione e coordinamento',
    'MONITORAGGIO IN ITINERE ED EX POST': 'Amministrazione e segreteria',
    'VERIFICA/VALUTAZIONE DEGLI APPRENDIMENTI': 'Esami',
    'SERVIZI AL LAVORO': 'Amministrazione e segreteria',
    'ELABORAZIONE REPORTS E STUDI': 'Amministrazione e segreteria',
    'AMMINISTRAZIONE': 'Amministrazione e segreteria',
    'SELEZIONE': 'Amministrazione e segreteria',
    'CODOCENZA ESAME': 'Esami',
    'ATTIVITÀ DI RECUPERO': 'Docenza',
    'COACHING': 'Tutoraggio',
    'DIREZIONE': 'Amministrazione e segreteria',
    'AUSILIARIO': 'Tutoraggio',
    'RICERCA': 'Promozione',
    'SCOUTING': 'Promozione',
    'SEGRETERIA': 'Amministrazione e segreteria',
    'ANALISI DEI BISOGNI': 'Progettazione e coordinamento',
    'FORMAZIONE IN ASSETTO LAVORATIVO': 'Amministrazione e segreteria'
})

fatture = fatture[['IDedizione', 'Attivita', 'sngTotale' ]].groupby(['IDedizione', 'Attivita']).sum()
fatture = fatture.reset_index(level=['IDedizione', 'Attivita'])
fatture = fatture.pivot(index='IDedizione', columns='Attivita', values='sngTotale')
fatture.fillna(0)

dati = dati.join(fatture)

# %%
dati
# Out:
#               AnnoAmm  AnnoBando  \
# IDedizione
# 26970       2018/2019  2018/2019
# 27021       2018/2019  2018/2019
# 25917       2018/2019  2018/2019
# 26104       2018/2019  2018/2019
# 26853       2018/2019  2018/2019
# ...               ...        ...
# 31122       2021/2022  2021/2022
# 31139       2021/2022  2020/2021
# 31138       2021/2022  2020/2021
# 31142       2021/2022  2021/2022
# 31144       2021/2022  2021/2022
#
#                                                     TipoBando  \
# IDedizione
# 26970             BANDO ATTIVITÀ A PAGAMENTO - LIBERO MERCATO
# 27021             BANDO ATTIVITÀ A PAGAMENTO - LIBERO MERCATO
# 25917             BANDO ATTIVITÀ A PAGAMENTO - LIBERO MERCATO
# 26104             BANDO ATTIVITÀ A PAGAMENTO - LIBERO MERCATO
# 26853             BANDO ATTIVITÀ A PAGAMENTO - LIBERO MERCATO
# ...                                                       ...
# 31122       BANDO CON GARA DI APPALTO AMMINISTRAZIONE PUBB...
# 31139                         BANDO FONDI INTER-PROFESSIONALI
# 31138                         BANDO FONDI INTER-PROFESSIONALI
# 31142       BANDO AMMINISTRAZIONE PROVINCIALE PER L'APPREN...
# 31144                         BANDO FONDI INTER-PROFESSIONALI
#
#                                          TipoFormativoInterno  \
# IDedizione
# 26970                   ATTIVITÀ DI RECUPERO DEBITI FORMATIVI
# 27021                                   FORMAZIONE PERMANENTE
# 25917                                   FORMAZIONE PERMANENTE
# 26104                                   FORMAZIONE PERMANENTE
# 26853       FORMAZIONE CONTINUA (CORSI AZIENDALI PER OCCUP...
# ...                                                       ...
# 31122                      FORMAZIONE DETENUTI ED EX-DETENUTI
# 31139       FORMAZIONE CONTINUA (CORSI AZIENDALI PER OCCUP...
# 31138       FORMAZIONE CONTINUA (CORSI AZIENDALI PER OCCUP...
# 31142                       APPRENDISTATO PROFESSIONALIZZANTE
# 31144       FORMAZIONE CONTINUA (CORSI AZIENDALI PER OCCUP...
#
#                     SiglaSede  \
# IDedizione
# 26970                  VARESE
# 27021       BUSTO ARSIZIO 143
# 25917                 BERGAMO
# 26104                 CREMONA
# 26853                 BERGAMO
# ...                       ...
# 31122                  VARESE
# 31139       BUSTO ARSIZIO 143
# 31138                VIGEVANO
# 31142                   MELZO
# 31144                    COMO
#
#                                                 DescrEdizione  \
# IDedizione
# 26970                         SICUREZZA - RECUPERO DDIF 18/19
# 27021       FORMAZIONE FGAS IN PREPARAZIONE ESAME PATENTIN...
# 25917       TECNICHE DI MOVIMENTAZIONE MERCI IN AMBITO AER...
# 26104                                   SMALTO SEMIPERMANENTE
# 26853       AGGIORNAMENTO PER ADDETTI ALLE ATTIVITÀ DI RIM...
# ...                                                       ...
# 31122                   STRUMENTI E TECNICHE DI TINTEGGIATURA
# 31139       ENAIP LOMBARDIA ED.16 LAVORARE IN UN' OTTICA D...
# 31138       ENAIP LOMBARDIA ED.15 LAVORARE IN UN' OTTICA D...
# 31142       FORMAZIONE ESTERNA APPRENDISTI COMPETENZE TRAS...
# 31144       ENAIP LOMBARDIA ED.2 INNOVAZIONI DEI PROCESSI ...
#
#                                  CodiceEdizione  \
# IDedizione
# 26970           SICUREZZA - RECUPERO DDIF 18/19
# 27021                                      FGAS
# 25917                                    206678
# 26104                             SMALTO SEMIP.
# 26853       AGGIORNAMENTO ADDETTI AMIANTO 4 ED.
# ...                                         ...
# 31122                      1761 - TINTEGGIATURA
# 31139                  61952 - VECCHIO CONVENTO
# 31138                    61783 - INTERAZIENDALE
# 31142                                  237978.4
# 31144                              60944 - R.M.
#
#                                           TipoSettoreInt  IDprogetto  \
# IDedizione
# 26970                                          SICUREZZA        3060
# 27021       ELETTRICITÀ, ELETTRONICA, IMPIANTI ELETTRICI        3060
# 25917                                          TRASPORTI        3060
# 26104                               ESTETICA E BENESSERE        3060
# 26853                                           EDILIZIA        3060
# ...                                                  ...         ...
# 31122                                           EDILIZIA        3578
# 31139                   ALBERGHIERO E DELLA RISTORAZIONE        3580
# 31138                               ESTETICA E BENESSERE        3581
# 31142                                    INTERSETTORIALE        3582
# 31144                                    INTERSETTORIALE        3583
#
#            CodiceProgetto  ... NIscr NumeroDoti ImportoDoti  \
# IDedizione                 ...
# 26970           LIB 18-19  ...    34        0.0         0.0
# 27021           LIB 18-19  ...     8        0.0         0.0
# 25917           LIB 18-19  ...    18        0.0         0.0
# 26104           LIB 18-19  ...    10        0.0         0.0
# 26853           LIB 18-19  ...    15        0.0         0.0
# ...                   ...  ...   ...        ...         ...
# 31122           CC VARESE  ...     0        0.0         0.0
# 31139       0015711-61952  ...     0        0.0         0.0
# 31138       0015711-61783  ...     0        0.0         0.0
# 31142           MI2012670  ...     1        0.0         0.0
# 31144       0010976-60944  ...     0        0.0         0.0
#
#            Amministrazione e segreteria     Docenza  Esami  Orientamento  \
# IDedizione
# 26970                               NaN  174.720001    NaN           NaN
# 27021                               NaN  867.519989    NaN           NaN
# 25917                               NaN         NaN    NaN           NaN
# 26104                               NaN   92.000000    NaN           NaN
# 26853                               NaN  800.320007    NaN           NaN
# ...                                 ...         ...    ...           ...
# 31122                               NaN         NaN    NaN           NaN
# 31139                               NaN         NaN    NaN           NaN
# 31138                               NaN         NaN    NaN           NaN
# 31142                               NaN         NaN    NaN           NaN
# 31144                               NaN         NaN    NaN           NaN
#
#             Progettazione e coordinamento  Promozione  Tutoraggio
# IDedizione
# 26970                                 NaN         NaN         NaN
# 27021                                 NaN         NaN         NaN
# 25917                                 NaN         NaN         NaN
# 26104                                 NaN         NaN         NaN
# 26853                                 NaN         NaN         NaN
# ...                                   ...         ...         ...
# 31122                                 NaN         NaN         NaN
# 31139                                 NaN         NaN         NaN
# 31138                                 NaN         NaN         NaN
# 31142                                 NaN         NaN         NaN
# 31144                                 NaN         NaN         NaN
#
# [3913 rows x 28 columns]

# %%
# Aggiungi i dati sulle parcelle collaboratori
parcelle = readSqlData('Costi/Parcelle collaboratori.sql')
parcelle = parcelle[parcelle['IDedizione'].notna()]

parcelle['Attivita'] = parcelle['TipoCausaleParcella'].map({
    'PRATICHE NOTARILI PER ATS': 'Amministrazione e segreteria',
    'ALTRO': 'Amministrazione e segreteria',
    'COMMISSIONE DI ESAME': 'Esami',
    'ADEMPIMENTI L.626': 'Amministrazione e segreteria',
    'CONSULENZA': 'Amministrazione e segreteria'
})

parcelle = parcelle[['IDedizione', 'Attivita', 'sngTotale' ]].groupby(['IDedizione', 'Attivita']).sum()
parcelle = parcelle.reset_index(level=['IDedizione', 'Attivita'])

parcelle = parcelle.pivot(index='IDedizione', columns='Attivita', values='sngTotale')
parcelle.fillna(0)
parcelle = parcelle.reset_index()
parcelle

dati.merge(parcelle, how='left', on='IDedizione').set_index()
#pd.merge(dati, parcelle, on=parcelle.columns)#.set_index(cols).sum(axis=1)
#dati = dati.join(parcelle)
#dati['ParcelleCollaboratori'] = dati['ParcelleCollaboratori'].fillna(0)
# Out:
# Attivita  IDedizione  Amministrazione e segreteria   Esami
# 0            16076.0                   1768.000000     NaN
# 1            25887.0                   2105.129883     NaN
# 2            25905.0                    622.200012     NaN
# 3            26286.0                           NaN   840.0
# 4            26287.0                           NaN   550.0
# 5            26808.0                           NaN   368.0
# 6            27118.0                   3150.000000     NaN
# 7            27478.0                           NaN  1056.0
# 8            27989.0                   1012.000000     NaN
# 9            28098.0                    640.000000     NaN
# 10           28280.0                    146.000000     NaN
# 11           28803.0                    338.000000     NaN
# 12           28845.0                   8750.000000     NaN
# 13           28941.0                           NaN   344.0
# 14           29119.0                    253.759995     NaN
# 15           30391.0                    702.000000     NaN
# 16           30392.0                    502.000000     NaN

# %%
# Salva i dati in excel
dati = dati.reset_index(level=['Attivita'])
dati.to_excel("output.xlsx", sheet_name='data')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [75], in <cell line: 2>()
#       1 # Salva i dati in excel
# ----> 2 dati = dati.reset_index(level=['Attivita'])
#       3 dati.to_excel("output.xlsx", sheet_name='data')
#
# File /opt/anaconda3/envs/jupyter/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/jupyter/lib/python3.9/site-packages/pandas/core/frame.py:5793, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill)
#    5791 if not isinstance(level, (tuple, list)):
#    5792     level = [level]
# -> 5793 level = [self.index._get_level_number(lev) for lev in level]
#    5794 if len(level) < self.index.nlevels:
#    5795     new_index = self.index.droplevel(level)
#
# File /opt/anaconda3/envs/jupyter/lib/python3.9/site-packages/pandas/core/frame.py:5793, in <listcomp>(.0)
#    5791 if not isinstance(level, (tuple, list)):
#    5792     level = [level]
# -> 5793 level = [self.index._get_level_number(lev) for lev in level]
#    5794 if len(level) < self.index.nlevels:
#    5795     new_index = self.index.droplevel(level)
#
# File /opt/anaconda3/envs/jupyter/lib/python3.9/site-packages/pandas/core/indexes/base.py:1936, in Index._get_level_number(self, level)
#    1935 def _get_level_number(self, level) -> int:
# -> 1936     self._validate_index_level(level)
#    1937     return 0
#
# File /opt/anaconda3/envs/jupyter/lib/python3.9/site-packages/pandas/core/indexes/base.py:1931, in Index._validate_index_level(self, level)
#    1927         raise IndexError(
#    1928             f"Too many levels: Index has only 1 level, not {level + 1}"
#    1929         )
#    1930 elif level != self.name:
# -> 1931     raise KeyError(
#    1932         f"Requested level ({level}) does not match index name ({self.name})"
#    1933     )
#
# KeyError: 'Requested level (Attivita) does not match index name (IDedizione)'
